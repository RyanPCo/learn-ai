# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F

import numpy as np

USE_GPU = True
dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print_every = 100
print('using device:', device)
# Out:
# using device: cuda

# %%
NUM_TRAIN = 49000

# preprocess data by subtracting mean RGB and dividing by std (hardcoded)
transform = T.Compose([
    T.ToTensor(),
    T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# Dataset object for each split (train / val / test)
# Datasets load examples one at a time, so wrap in Dataloader which iterates through Dataset to form minibatches
# Divide CIFAR-10 training set into train and val by passing Sampler object telling it how it should sample from underlying Dataset
cifar10_train = dset.CIFAR10('./datasets', train=True, download=True, transform=transform)
loader_train = DataLoader(cifar10_train, batch_size=64, sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = dset.CIFAR10('./datasets', train=True, download=True, transform=transform)
loader_val = DataLoader(cifar10_val, batch_size=64, sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = dset.CIFAR10('./datasets', train=False, download=True, transform=transform)
loader_test = DataLoader(cifar10_test, batch_size=64)
# Out:
# 100.0%

# %%
test = torch.Tensor(([1,2,3], [4,5,6]))
print(test)
print(torch.flatten(test))
print(test.dtype)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])
# tensor([1., 2., 3., 4., 5., 6.])
# torch.float32

# %%
# Input img size: 32 x 32 x 3

# [CONV -> ReLU] -> [CONV -> ReLU] -> [FC]
# channel_1: 5x5 filters, zero_padding of 2
# channel_2: 3x3 filters, zero_padding of 1

class ThreeLayerConvNet(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, num_classes):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, channel_1, 5, padding=2)
        nn.init.kaiming_normal_(self.conv1.weight)

        self.conv2 = nn.Conv2d(channel_1, channel_2, 3, padding=1)
        nn.init.kaiming_normal_(self.conv2.weight)

        self.fc = nn.Linear(channel_2 * 32 * 32, num_classes)
        nn.init.kaiming_normal_(self.fc.weight)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.shape[0], -1)
        scores = self.fc(x)
        return scores
    
def test_ThreeLayerConvNet():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = ThreeLayerConvNet(in_channel=3, channel_1=12, channel_2=8, num_classes=10)
    scores = model(x)
    print(scores.shape)

test_ThreeLayerConvNet()
# Out:
# torch.Size([64, 10])

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')

    num_correct = 0
    num_samples = 0
    model.eval()
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=dtype)
            scores = model(x)
            _, preds = scores.max(dim=1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
def train(model, optimizer, epochs=1):
    model = model.to(device=device)
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            model.train()
            x = x.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            optimizer.zero_grad()

            loss.backward()

            optimizer.step()

            if t % print_every == 0:
                print('Iteration %d, loss = %.4f' % (t, loss.item()))
                check_accuracy(loader_val, model)
                print()

# %%
learning_rate = 1e-3
channel_1 = 32
channel_2 = 16
num_classes = 10

model = ThreeLayerConvNet(3, channel_1, channel_2, num_classes)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer, epochs=10)
# Out:
# Iteration 0, loss = 2.8570
# Checking accuracy on validation set
# Got 125 / 1000 correct (12.50)
#
# Iteration 100, loss = 1.8136
# Checking accuracy on validation set
# Got 376 / 1000 correct (37.60)
#
# Iteration 200, loss = 1.2723
# Checking accuracy on validation set
# Got 467 / 1000 correct (46.70)
#
# Iteration 300, loss = 1.3818
# Checking accuracy on validation set
# Got 498 / 1000 correct (49.80)
#
# Iteration 400, loss = 1.5267
# Checking accuracy on validation set
# Got 532 / 1000 correct (53.20)
#
# Iteration 500, loss = 1.2989
# Checking accuracy on validation set
# Got 564 / 1000 correct (56.40)
#
# Iteration 600, loss = 1.3560
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
#
# Iteration 700, loss = 1.0702
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
#
# Iteration 0, loss = 1.0862
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
#
# Iteration 100, loss = 0.8761
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 200, loss = 0.7956
# Checking accuracy on validation set
# Got 593 / 1000 correct (59.30)
#
# Iteration 300, loss = 1.0994
# Checking accuracy on validation set
# Got 611 / 1000 correct (61.10)
#
# Iteration 400, loss = 0.9949
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
#
# Iteration 500, loss = 0.9245
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
#
# Iteration 600, loss = 1.2700
# Checking accuracy on validation set
# Got 590 / 1000 correct (59.00)
#
# Iteration 700, loss = 0.8179
# Checking accuracy on validation set
# Got 577 / 1000 correct (57.70)
#
# Iteration 0, loss = 0.6369
# Checking accuracy on validation set
# Got 593 / 1000 correct (59.30)
#
# Iteration 100, loss = 0.9272
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
#
# Iteration 200, loss = 0.9302
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
#
# Iteration 300, loss = 0.9149
# Checking accuracy on validation set
# Got 590 / 1000 correct (59.00)
#
# Iteration 400, loss = 0.9665
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
#
# Iteration 500, loss = 0.7803
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
#
# Iteration 600, loss = 0.8962
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
#
# Iteration 700, loss = 0.9049
# Checking accuracy on validation set
# Got 599 / 1000 correct (59.90)
#
# Iteration 0, loss = 0.5890
# Checking accuracy on validation set
# Got 612 / 1000 correct (61.20)
#
# Iteration 100, loss = 0.7492
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
#
# Iteration 200, loss = 0.4738
# Checking accuracy on validation set
# Got 600 / 1000 correct (60.00)
#
# Iteration 300, loss = 0.6141
# Checking accuracy on validation set
# Got 609 / 1000 correct (60.90)
#
# Iteration 400, loss = 0.6205
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
#
# Iteration 500, loss = 0.8608
# Checking accuracy on validation set
# Got 589 / 1000 correct (58.90)
#
# Iteration 600, loss = 0.9174
# Checking accuracy on validation set
# Got 584 / 1000 correct (58.40)
#
# Iteration 700, loss = 0.8479
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Iteration 0, loss = 0.6226
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
#
# Iteration 100, loss = 0.5463
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
#
# Iteration 200, loss = 0.4798
# Checking accuracy on validation set
# Got 584 / 1000 correct (58.40)
#
# Iteration 300, loss = 0.7593
# Checking accuracy on validation set
# Got 586 / 1000 correct (58.60)
#
# Iteration 400, loss = 0.5784
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
#
# Iteration 500, loss = 0.5125
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 600, loss = 0.7728
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 700, loss = 0.6901
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
#
# Iteration 0, loss = 0.4351
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
#
# Iteration 100, loss = 0.4505
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
#
# Iteration 200, loss = 0.2558
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
#
# Iteration 300, loss = 0.4583
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
#
# Iteration 400, loss = 0.6011
# Checking accuracy on validation set
# Got 569 / 1000 correct (56.90)
#
# Iteration 500, loss = 0.7249
# Checking accuracy on validation set
# Got 573 / 1000 correct (57.30)
#
# Iteration 600, loss = 0.4535
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
#
# Iteration 700, loss = 0.5855
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
#
# Iteration 0, loss = 0.3707
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 100, loss = 0.6094
# Checking accuracy on validation set
# Got 574 / 1000 correct (57.40)
#
# Iteration 200, loss = 0.3401
# Checking accuracy on validation set
# Got 568 / 1000 correct (56.80)
#
# Iteration 300, loss = 0.4031
# Checking accuracy on validation set
# Got 560 / 1000 correct (56.00)
#
# Iteration 400, loss = 0.5648
# Checking accuracy on validation set
# Got 576 / 1000 correct (57.60)
#
# Iteration 500, loss = 0.5280
# Checking accuracy on validation set
# Got 576 / 1000 correct (57.60)
#
# Iteration 600, loss = 0.4718
# Checking accuracy on validation set
# Got 568 / 1000 correct (56.80)
#
# Iteration 700, loss = 0.3759
# Checking accuracy on validation set
# Got 561 / 1000 correct (56.10)
#
# Iteration 0, loss = 0.1756
# Checking accuracy on validation set
# Got 568 / 1000 correct (56.80)
#
# Iteration 100, loss = 0.2806
# Checking accuracy on validation set
# Got 577 / 1000 correct (57.70)
#
# Iteration 200, loss = 0.4111
# Checking accuracy on validation set
# Got 569 / 1000 correct (56.90)
#
# Iteration 300, loss = 0.3865
# Checking accuracy on validation set
# Got 573 / 1000 correct (57.30)
#
# Iteration 400, loss = 0.3585
# Checking accuracy on validation set
# Got 560 / 1000 correct (56.00)
#
# Iteration 500, loss = 0.2903
# Checking accuracy on validation set
# Got 577 / 1000 correct (57.70)
#
# Iteration 600, loss = 0.5225
# Checking accuracy on validation set
# Got 557 / 1000 correct (55.70)
#
# Iteration 700, loss = 0.2412
# Checking accuracy on validation set
# Got 542 / 1000 correct (54.20)
#
# Iteration 0, loss = 0.1722
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
#
# Iteration 100, loss = 0.3381
# Checking accuracy on validation set
# Got 555 / 1000 correct (55.50)
#
# Iteration 200, loss = 0.3273
# Checking accuracy on validation set
# Got 572 / 1000 correct (57.20)
#
# Iteration 300, loss = 0.2683
# Checking accuracy on validation set
# Got 555 / 1000 correct (55.50)
#
# Iteration 400, loss = 0.2613
# Checking accuracy on validation set
# Got 570 / 1000 correct (57.00)
#
# Iteration 500, loss = 0.3541
# Checking accuracy on validation set
# Got 558 / 1000 correct (55.80)
#
# Iteration 600, loss = 0.2619
# Checking accuracy on validation set
# Got 573 / 1000 correct (57.30)
#
# Iteration 700, loss = 0.7105
# Checking accuracy on validation set
# Got 572 / 1000 correct (57.20)
#
# Iteration 0, loss = 0.1894
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
#
# Iteration 100, loss = 0.1479
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
#
# Iteration 200, loss = 0.2143
# Checking accuracy on validation set
# Got 570 / 1000 correct (57.00)
#
# Iteration 300, loss = 0.3619
# Checking accuracy on validation set
# Got 556 / 1000 correct (55.60)
#
# Iteration 400, loss = 0.2215
# Checking accuracy on validation set
# Got 550 / 1000 correct (55.00)
#
# Iteration 500, loss = 0.1269
# Checking accuracy on validation set
# Got 563 / 1000 correct (56.30)
#
# Iteration 600, loss = 0.1995
# Checking accuracy on validation set
# Got 570 / 1000 correct (57.00)
#
# Iteration 700, loss = 0.2119
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)

# %%
class ConvNet(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, channel_3, channel_4, num_classes):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, channel_1, 3, padding=1)
        nn.init.kaiming_normal_(self.conv1.weight)

        self.conv2 = nn.Conv2d(channel_1, channel_2, 3, padding=1)
        nn.init.kaiming_normal_(self.conv2.weight)

        self.pool1 = nn.MaxPool2d(2, 2)

        self.conv3 = nn.Conv2d(channel_2, channel_3, 3, padding=1)
        nn.init.kaiming_normal_(self.conv3.weight)

        self.conv4 = nn.Conv2d(channel_3, channel_4, 3, padding=1)
        nn.init.kaiming_normal_(self.conv4.weight)

        self.pool2 = nn.MaxPool2d(2, 2)

        self.fc = nn.Linear(channel_4 * 8 * 8, num_classes)
        nn.init.kaiming_normal_(self.fc.weight)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool1(x)
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.pool2(x)
        x = x.view(x.shape[0], -1)
        scores = self.fc(x)
        return scores
    
def test_ConvNet():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = ConvNet(in_channel=3, channel_1=32, channel_2=32, channel_3=32, channel_4=32, num_classes=10)
    scores = model(x)
    print(scores.shape)

test_ConvNet()
# Out:
# torch.Size([64, 10])

# %%
learning_rate = 1e-3
channel_1 = 32
channel_2 = 32
channel_3 = 32
channel_4 = 32
num_classes = 10

model = ConvNet(3, channel_1, channel_2, channel_3, channel_4, num_classes)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer, epochs=10)
# Out:
# Iteration 0, loss = 2.7879
# Checking accuracy on validation set
# Got 137 / 1000 correct (13.70)
#
# Iteration 100, loss = 1.5430
# Checking accuracy on validation set
# Got 430 / 1000 correct (43.00)
#
# Iteration 200, loss = 1.5208
# Checking accuracy on validation set
# Got 502 / 1000 correct (50.20)
#
# Iteration 300, loss = 1.3502
# Checking accuracy on validation set
# Got 507 / 1000 correct (50.70)
#
# Iteration 400, loss = 1.2136
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
#
# Iteration 500, loss = 1.2181
# Checking accuracy on validation set
# Got 573 / 1000 correct (57.30)
#
# Iteration 600, loss = 1.1822
# Checking accuracy on validation set
# Got 586 / 1000 correct (58.60)
#
# Iteration 700, loss = 1.4702
# Checking accuracy on validation set
# Got 603 / 1000 correct (60.30)
#
# Iteration 0, loss = 1.0568
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
#
# Iteration 100, loss = 0.9796
# Checking accuracy on validation set
# Got 643 / 1000 correct (64.30)
#
# Iteration 200, loss = 0.9742
# Checking accuracy on validation set
# Got 635 / 1000 correct (63.50)
#
# Iteration 300, loss = 0.9198
# Checking accuracy on validation set
# Got 647 / 1000 correct (64.70)
#
# Iteration 400, loss = 0.9083
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 500, loss = 0.8755
# Checking accuracy on validation set
# Got 645 / 1000 correct (64.50)
#
# Iteration 600, loss = 0.9263
# Checking accuracy on validation set
# Got 667 / 1000 correct (66.70)
#
# Iteration 700, loss = 0.7824
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Iteration 0, loss = 0.8868
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 100, loss = 0.7687
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
#
# Iteration 200, loss = 0.9188
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Iteration 300, loss = 0.9161
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# Iteration 400, loss = 1.0193
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Iteration 500, loss = 0.9419
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 600, loss = 0.8016
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 700, loss = 0.5923
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
#
# Iteration 0, loss = 0.6319
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 100, loss = 0.5454
# Checking accuracy on validation set
# Got 689 / 1000 correct (68.90)
#
# Iteration 200, loss = 0.8008
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 300, loss = 0.6737
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 400, loss = 0.7730
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 500, loss = 1.0691
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 600, loss = 0.5876
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 700, loss = 0.9376
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 0, loss = 0.7176
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 100, loss = 0.6970
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 200, loss = 0.8682
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 300, loss = 0.6688
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 400, loss = 0.8533
# Checking accuracy on validation set
# Got 711 / 1000 correct (71.10)
#
# Iteration 500, loss = 0.5601
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 600, loss = 0.6040
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 700, loss = 0.6810
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 0, loss = 0.8320
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 100, loss = 0.7331
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 200, loss = 0.6278
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 300, loss = 0.6764
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 400, loss = 0.7111
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 500, loss = 0.6608
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 600, loss = 0.7271
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 700, loss = 0.7062
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 0, loss = 0.5044
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 100, loss = 0.4820
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 200, loss = 0.6598
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 300, loss = 0.5766
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 400, loss = 0.2702
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 500, loss = 0.6867
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 600, loss = 0.6464
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 700, loss = 0.5797
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 0, loss = 0.5349
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 100, loss = 0.5421
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 200, loss = 0.4676
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 300, loss = 0.5644
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 400, loss = 0.5114
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 500, loss = 0.4572
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 600, loss = 0.4757
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 700, loss = 0.7284
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 0, loss = 0.4651
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 100, loss = 0.4424
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 200, loss = 0.5979
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 300, loss = 0.4706
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 400, loss = 0.7628
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Iteration 500, loss = 0.8248
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 600, loss = 0.6176
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 700, loss = 0.3770
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 0, loss = 0.3986
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 100, loss = 0.4111
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 200, loss = 0.3855
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 300, loss = 0.5155
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 400, loss = 0.3778
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 500, loss = 0.4821
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 600, loss = 0.5808
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 700, loss = 0.5914
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)

# %%
check_accuracy(loader_test, model)
# Out:
# Checking accuracy on test set
# Got 7259 / 10000 correct (72.59)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channel, out_channel):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channel, out_channel, 3, padding=1)
        self.bn = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, 3, padding=1)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn(out)
        out = F.relu(out)
        out = self.conv2(out)

        out += identity
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, in_channel, channel_1, channel_2, channel_3, channel_4, channel_5, num_classes):
        super().__init__()

        self.conv = nn.Conv2d(in_channel, channel_1, 3, padding=1)
        self.block1 = ResidualBlock(channel_1, channel_2)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.block2 = ResidualBlock(channel_3, channel_4)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(channel_4 * 8 * 8, channel_5)
        self.fc2 = nn.Linear(channel_5, num_classes)

    def forward(self, x):
        x = F.relu(self.conv(x))
        x = self.block1(x)
        x = self.pool1(x)
        x = self.block2(x)
        x = self.pool2(x)
        x = x.view(x.shape[0], -1)
        x = self.fc1(x)
        scores = self.fc2(x)
        return scores
    
def test_ResNet():
    x = torch.zeros((64, 3, 32, 32), dtype=dtype)
    model = ResNet(in_channel=3, channel_1=32, channel_2=32, channel_3=32, channel_4=32, channel_5=32, num_classes=10)
    scores = model(x)
    print(scores.shape)

test_ResNet()
# Out:
# torch.Size([64, 10])

# %%
learning_rate = 1e-3
channel_1 = 64
channel_2 = 64
channel_3 = 64
channel_4 = 64
channel_5 = 64
num_classes = 10

model = ResNet(3, channel_1, channel_2, channel_3, channel_4, channel_5, num_classes)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

train(model, optimizer, epochs=10)
# Out:
# Iteration 0, loss = 2.3899
# Checking accuracy on validation set
# Got 152 / 1000 correct (15.20)
#
# Iteration 100, loss = 1.7146
# Checking accuracy on validation set
# Got 408 / 1000 correct (40.80)
#
# Iteration 200, loss = 1.4834
# Checking accuracy on validation set
# Got 497 / 1000 correct (49.70)
#
# Iteration 300, loss = 1.5038
# Checking accuracy on validation set
# Got 519 / 1000 correct (51.90)
#
# Iteration 400, loss = 1.2709
# Checking accuracy on validation set
# Got 575 / 1000 correct (57.50)
#
# Iteration 500, loss = 0.9742
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
#
# Iteration 600, loss = 0.9720
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
#
# Iteration 700, loss = 0.9465
# Checking accuracy on validation set
# Got 642 / 1000 correct (64.20)
#
# Iteration 0, loss = 1.1325
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
#
# Iteration 100, loss = 0.9750
# Checking accuracy on validation set
# Got 647 / 1000 correct (64.70)
#
# Iteration 200, loss = 0.8180
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Iteration 300, loss = 0.8046
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
#
# Iteration 400, loss = 0.9563
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 500, loss = 1.0836
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
#
# Iteration 600, loss = 0.8353
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Iteration 700, loss = 0.7624
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Iteration 0, loss = 0.7050
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 100, loss = 0.7955
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 200, loss = 1.0095
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 300, loss = 0.7315
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 400, loss = 0.7407
# Checking accuracy on validation set
# Got 691 / 1000 correct (69.10)
#
# Iteration 500, loss = 0.6150
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 600, loss = 0.9795
# Checking accuracy on validation set
# Got 711 / 1000 correct (71.10)
#
# Iteration 700, loss = 0.7088
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 0, loss = 0.6441
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 100, loss = 0.5133
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 200, loss = 0.9806
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 300, loss = 0.6942
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 400, loss = 0.6306
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 500, loss = 0.7830
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 600, loss = 0.8444
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 700, loss = 0.6667
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 0, loss = 0.4036
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 100, loss = 0.5187
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Iteration 200, loss = 0.6062
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Iteration 300, loss = 0.6162
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 400, loss = 0.6137
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 500, loss = 0.5978
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 600, loss = 0.6246
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 700, loss = 0.4636
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
#
# Iteration 0, loss = 0.5678
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 100, loss = 0.4688
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Iteration 200, loss = 0.6139
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 300, loss = 0.4896
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Iteration 400, loss = 0.6254
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
#
# Iteration 500, loss = 0.5467
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Iteration 600, loss = 0.4226
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Iteration 700, loss = 0.5835
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Iteration 0, loss = 0.4097
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 100, loss = 0.6987
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 200, loss = 0.3909
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
#
# Iteration 300, loss = 0.3996
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Iteration 400, loss = 0.5231
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 500, loss = 0.6358
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Iteration 600, loss = 0.4210
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Iteration 700, loss = 0.4116
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Iteration 0, loss = 0.4153
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 100, loss = 0.3591
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 200, loss = 0.2331
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 300, loss = 0.6553
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Iteration 400, loss = 0.4139
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Iteration 500, loss = 0.5860
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 600, loss = 0.4021
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Iteration 700, loss = 0.5734
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 0, loss = 0.3444
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Iteration 100, loss = 0.3769
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Iteration 200, loss = 0.3327
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Iteration 300, loss = 0.1933
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 400, loss = 0.3842
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Iteration 500, loss = 0.4579
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 600, loss = 0.3494
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Iteration 700, loss = 0.3729
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 0, loss = 0.2641
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
#
# Iteration 100, loss = 0.3666
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Iteration 200, loss = 0.2084
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
#
# Iteration 300, loss = 0.1865
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Iteration 400, loss = 0.2126
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
#
# Iteration 500, loss = 0.3967
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 600, loss = 0.4657
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Iteration 700, loss = 0.2937
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)

# %%
check_accuracy(loader_test, model)
# Out:
# Checking accuracy on test set
# Got 7546 / 10000 correct (75.46)
